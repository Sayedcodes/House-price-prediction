# %%
def greet(name):
    return "Hello, " + name + "!"

# %%
greet("Hamza")
# --- IGNORE ---
# Out:
# 'Hello, Hamza!'

# %%
from tttt import *

# %%
frequency("Hamza")
# Out:
# {'H': 1, 'a': 2, 'm': 1, 'z': 1}
