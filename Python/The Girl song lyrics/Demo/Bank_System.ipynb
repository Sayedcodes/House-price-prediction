# %% [markdown]
# Bank System

# %%
# Øpen account

def open_account(account_name,account_phone_number):
    return f"Account '{account_name}' with phone number '{account_phone_number}' has been opened."

# %%
open_account("Sayed_Hamza",7838015309)
# Out:
# "Account 'Sayed_Hamza' with phone number '7838015309' has been opened."
